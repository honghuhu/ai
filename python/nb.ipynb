00:00&ts=2023-04-13T02:04:13.3686832+00:00&rwred=0&wls=2&lka=0&lkt=0&TH=&r=1&mta=0&e=M3hWi5LBKDZlUKxlURvZall5XPxUzhB1OFFhfg1R_yfzFjZ9Y9Vj5ezAcT8OP5aTMgwKc7gHpeHh1FiXIfoZow&A=; ipv6=hit=1681355056634&t=4; SRCHHPGUSR=BRW=NOTP&BRH=S&CW=648&CH=381&SCW=1204&SCH=398&SRCHLANG=zh-Hans&PV=13.3.1&PRVCW=1496&PRVCH=796&DPR=1.0&UTC=480&DM=0&EXLTT=8&HV=1681351503; _clsk=csliuw|1681351508224|3|1|q.clarity.ms/collect'),

cookies = dict([l.split("=", 1) for l in cookie_str.split("; ")])
print(cookies)
response = requests.get('https://www.bing.com/turing/conversation/create', cookies = cookies)
print(response.text)
# Out:
# {'SRCHD': 'AF=SHORUN', 'SRCHUID': 'V=2&GUID=97F2699FA97B47AEA370F4926C1F51C8&dmnchg=1', '_tarLang': 'default=zh-Hans', '_TTSS_IN': 'hist=WyJlbiIsImF1dG8tZGV0ZWN0Il0=', '_TTSS_OUT': 'hist=WyJ6aC1IYW5zIl0=', 'SnrOvr': 'X=rebateson', 'ANON': 'A=C48825485D12B01197F4ADA6FFFFFFFF&E=1c2e&W=1', 'WLID': 'mPMRVAcf05UxJL371uQHh7OqN7qapKsbWedt3JMGIhafdLo3uftRe+lCv0+a3WFchWSKrsEZ6pPy+5a/51v4sDhvPs5MkLnzbRb4B8+iI8s=', 'ABDEF': 'V=13&ABDV=11&MRNB=1680701066236&MRB=0', 'MUID': '2E1CF8589D546801164BEAB29C1169C7', '_EDGE_V': '1', 'MUIDB': '2E1CF8589D546801164BEAB29C1169C7', 'ANIMIA': 'FRE=1', 'MMCASM': 'ID=F0E4CC1C0E5D49C592EB73C383A0000B', 'MicrosoftApplicationsTelemetryDeviceId': 'c34ac587-1ac2-4383-b2f3-2a1a3eb963fe', 'WLS': 'C=f77a2d85acd8034b&N=tieniu', '_EDGE_S': 'SID=1AD684DF7F0561B3262A962E7EFE6090&mkt=en-us&ui=zh-cn', 'SNRHOP': 'I=&TS=', 'msaoptout': '0', '_UR': 'QS=0&TQS=0', '_HPVN': 'CS=eyJQbiI6eyJDbiI6NCwiU3QiOjAsIlFzIjowLCJQcm9kIjoiUCJ9LCJTYyI6eyJDbiI6NCwiU3QiOjAsIlFzIjowLCJQcm9kIjoiSCJ9L
# ...

# %%
# !curl https://www.bing.com/turing/conversation/create
# Out:
# {"result":{"value":"UnauthorizedRequest","message":"Sorry, you need to login first to access this service."}}
